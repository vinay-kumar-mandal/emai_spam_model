# %%
print("vinay kumar mandal")
# Out:
# vinay kumar mandal

# %%
def my_cun(x, y):
    return x + y

# %%
my_cun(100, 500)
# Out:
# 600

# %%
z = 5
def my_num(x, y, z):
    if z > 1:
        return z*(x + y)
    else:
        return z / (x + y)

# %%
my_num(5, 6, 2)
# Out:
# 22

# %%
a = []

def fun():
    for i in range(5):
        a.append(i)

# %%
fun()

# %%
a
# Out:
# [0, 1, 2, 3, 4]

# %%
def f():
    a = 5
    b = 6
    c = 8
    return {"a":a, "b":b, "c":c}

# %%
f()
# Out:
# {'a': 5, 'b': 6, 'c': 8}
